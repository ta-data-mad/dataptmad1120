# %% [markdown]
# # Data Cleaning
#
# #### 1. Import pandas library.

# %%
import pandas as pd

# %% [markdown]
# #### 2. Import pymysql and sqlalchemy as you have learnt in the lesson of importing/exporting data.

# %%
import pymysql

from sqlalchemy import create_engine

# %% [markdown]
# #### 3. Create a mysql engine to set the connection to the server. Check the connection details in [this link](https://relational.fit.cvut.cz/dataset/Stats).

# %%
#DIVIDED IN TWO STEPS, FIRST I WRITE AND CREATE THE CONNECTION STRING AND THEN I CREATE THE ENGINE
connection_string = 'mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/stats'

engine = create_engine(connection_string)

## SQLITE ????? NO ENTIENDO POR QUE NO ME SIRVE CON SQLITE. HELP! QUIERO APRENDER O ENTENDER PORQUE SE USA O NO
#conn_str = f'sqlite:////guest:relational@relational.fit.cvut.cz:3306/stats'
#engine = create_engine(conn_str)

# %% [markdown]
# #### 4. Import the users table.

# %%
#WITH THIS STEP I WAS LOOKING FOR A WAY TO FIND/LIST ALL THE TABLE NAMES. TO MAKE SURE I GET RIGHT THE NAMES IF THEY ARE NOT KNOWN

data_query_all_tables_info = pd.read_sql_query("SELECT * FROM information_schema.tables WHERE table_schema ='stats'", engine)
data_query_all_tables_info
# Out:
#   TABLE_CATALOG TABLE_SCHEMA   TABLE_NAME  TABLE_TYPE  ENGINE  VERSION  \
# 0           def        stats       badges  BASE TABLE  InnoDB       10
# 1           def        stats     comments  BASE TABLE  InnoDB       10
# 2           def        stats  postHistory  BASE TABLE  InnoDB       10
# 3           def        stats    postLinks  BASE TABLE  InnoDB       10
# 4           def        stats        posts  BASE TABLE  InnoDB       10
# 5           def        stats         tags  BASE TABLE  InnoDB       10
# 6           def        stats        users  BASE TABLE  InnoDB       10
# 7           def        stats        votes  BASE TABLE  InnoDB       10
#
#   ROW_FORMAT  TABLE_ROWS  AVG_ROW_LENGTH  DATA_LENGTH  ...  AUTO_INCREMENT  \
# 0    Compact       79776              59      4734976  ...            None
# 1    Compact      164432             418     68780032  ...            None
# 2    Compact      317317            1182    375242752  ...            None
# ...

# %%
data_show_tables = pd.read_sql_query("show tables", engine)
data_show_tables
# Out:
#   Tables_in_stats
# 0          badges
# 1        comments
# 2     postHistory
# 3       postLinks
# 4           posts
# 5            tags
# 6           users
# 7           votes

# %%
data_column_names_in_users = pd.read_sql_query(
'''
SELECT `COLUMN_NAME` 
FROM `INFORMATION_SCHEMA`.`COLUMNS` 
WHERE `TABLE_SCHEMA`='stats' 
    AND `TABLE_NAME`='users'
''', engine)
data_column_names_in_users
# Out:
#         COLUMN_NAME
# 0                Id
# 1        Reputation
# 2      CreationDate
# 3       DisplayName
# 4    LastAccessDate
# 5        WebsiteUrl
# 6          Location
# 7           AboutMe
# 8             Views
# 9           UpVotes
# 10        DownVotes
# 11        AccountId
# 12              Age
# 13  ProfileImageUrl

# %%
#THIS, TO LIST ALL CONTENTS INSIDE THE users TABLE
data_all_from_users = pd.read_sql_query("SELECT * FROM users", engine)
data_all_from_users
# Out:
#           Id  Reputation        CreationDate     DisplayName  \
# 0         -1           1 2010-07-19 06:55:26       Community
# 1          2         101 2010-07-19 14:01:36    Geoff Dalgas
# 2          3         101 2010-07-19 15:34:50    Jarrod Dixon
# 3          4         101 2010-07-19 19:03:27          Emmett
# 4          5        6792 2010-07-19 19:03:57           Shane
# ...      ...         ...                 ...             ...
# 40320  55743           1 2014-09-13 21:03:50       AussieMeg
# 40321  55744           6 2014-09-13 21:39:30       Mia Maria
# 40322  55745         101 2014-09-13 23:45:27    tronbabylove
# 40323  55746         106 2014-09-14 00:29:41             GPP
# 40324  55747           1 2014-09-14 01:01:44  Shivam Agrawal
#
#            LastAccessDate                      WebsiteUrl            Location  \
# 0     2010-07-19 06:55:26  http://meta.stackexchange.com/  on the server farm
# ...

# %% [markdown]
# #### 5. Rename Id column to userId.

# %%
#THIS IS A TEMPORARY RENAME

data_rename_Id_column = pd.read_sql_query("SELECT Id AS userId FROM users", engine)
data_rename_Id_column
# Out:
#        userId
# 0          -1
# 1           2
# 2           3
# 3           4
# 4           5
# ...       ...
# 40320   55743
# 40321   55744
# 40322   55745
# 40323   55746
# 40324   55747
#
# [40325 rows x 1 columns]

# %% [markdown]
# #### 6. Import the posts table.

# %%
data_all_from_posts = pd.read_sql_query("SELECT * FROM posts", engine)
data_all_from_posts
# Out:
#            Id  PostTypeId  AcceptedAnswerId         CreaionDate  Score  \
# 0           1           1              15.0 2010-07-19 19:12:12     23
# 1           2           1              59.0 2010-07-19 19:12:57     22
# 2           3           1               5.0 2010-07-19 19:13:28     54
# 3           4           1             135.0 2010-07-19 19:13:31     13
# 4           5           2               NaN 2010-07-19 19:14:43     81
# ...       ...         ...               ...                 ...    ...
# 91971  115374           2               NaN 2014-09-13 23:45:39      2
# 91972  115375           1               NaN 2014-09-13 23:46:05      0
# 91973  115376           1               NaN 2014-09-14 01:27:54      1
# 91974  115377           2               NaN 2014-09-14 02:03:28      0
# 91975  115378           2               NaN 2014-09-14 02:09:23      0
#
#        ViewCount                                               Body  \
# ...

# %% [markdown]
# #### 7. Rename Id column to postId and OwnerUserId to userId.

# %%
data_column_names_in_posts = pd.read_sql_query(
'''
SELECT `COLUMN_NAME` 
FROM `INFORMATION_SCHEMA`.`COLUMNS` 
WHERE `TABLE_SCHEMA`='stats' 
    AND `TABLE_NAME`='posts'
''', engine)
data_column_names_in_posts
# Out:
#               COLUMN_NAME
# 0                      Id
# 1              PostTypeId
# 2        AcceptedAnswerId
# 3             CreaionDate
# 4                   Score
# 5               ViewCount
# 6                    Body
# 7             OwnerUserId
# 8         LasActivityDate
# 9                   Title
# 10                   Tags
# 11            AnswerCount
# 12           CommentCount
# 13          FavoriteCount
# 14       LastEditorUserId
# 15           LastEditDate
# 16     CommunityOwnedDate
# 17               ParentId
# 18             ClosedDate
# 19       OwnerDisplayName
# 20  LastEditorDisplayName

# %%
#THIS IS A TEMPORARY RENAME

data_rename_Id_OwnerUserId_columns = pd.read_sql_query("SELECT Id as postId,OwnerUserId as userId FROM posts", engine)
data_rename_Id_OwnerUserId_columns

#NO SON LOS MISMOS VALORES EN LOS INDEX QUE ME MUESTRA BAJO LA BUSQUEDA DE "SELECT * FROM posts", ASI QUE CREO QUE HAY ALGO MAL, PERO NO ENTIENDO EL PORQUE
# Out:
#        postId   userId
# 0          17      NaN
# 1          28      NaN
# 2          56      NaN
# 3         101      NaN
# 4         152      NaN
# ...       ...      ...
# 91971  115352  55734.0
# 91972  115360  55738.0
# 91973  115366  55742.0
# 91974  115370  55744.0
# 91975  115376  55746.0
#
# [91976 rows x 2 columns]

# %% [markdown]
# #### 8. Define new dataframes for users and posts with the following selected columns:
# **users columns**: userId, Reputation, Views, UpVotes, DownVotes
# **posts columns**: postId, Score, userID, ViewCount, CommentCount

# %%
users_columns = pd.read_sql_query("SELECT Id as userId,Reputation,Views,UpVotes, DownVotes FROM users",engine)
#users_columns
df_users_columns = pd.DataFrame(users_columns)
df_users_columns

posts_columns = pd.read_sql_query("SELECT Id as postId,Score,OwnerUserId as userId,ViewCount, CommentCount FROM posts",engine)
#posts_columns
df_posts_columns = pd.DataFrame(posts_columns)
#df_posts_columns
df_users_columns
# Out:
#        userId  Reputation  Views  UpVotes  DownVotes
# 0          -1           1      0     5007       1920
# 1           2         101     25        3          0
# 2           3         101     22       19          0
# 3           4         101     11        0          0
# 4           5        6792   1145      662          5
# ...       ...         ...    ...      ...        ...
# 40320   55743           1      0        0          0
# 40321   55744           6      1        0          0
# 40322   55745         101      0        0          0
# 40323   55746         106      1        0          0
# 40324   55747           1      0        0          0
#
# [40325 rows x 5 columns]

# %% [markdown]
# #### 9. Merge the new dataframes you have created, of users and posts.
# You will need to make an inner [merge](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html) of posts and users dataframes.

# %% [markdown]
# #### 10. How many missing values do you have in your merged dataframe? On which columns?

# %% [markdown]
# #### 11. You will need to make something with missing values.  Will you clean or filling them? Explain.
# **Remember** to check the results of your code before going to the next step.

# %% [markdown]
# #### 12. Adjust the data types in order to avoid future issues. Which ones should be changed?
