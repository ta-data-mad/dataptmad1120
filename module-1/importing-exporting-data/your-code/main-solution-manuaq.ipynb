# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %% [markdown]
# # Challenge 1 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
# your code here

import pandas as pd

import pymysql

from sqlalchemy import create_engine

sqlitedb_abs_path = '/Users/manuelaquino/Desktop/juliarochflores.db'

connection_string = f'sqlite:///{sqlitedb_abs_path}'

engine = create_engine(connection_string)

# %%
# list all tables in database
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", engine)
# Out:
#             name
# 0      rank_info
# 1  personal_info
# 2  business_info

# %%
pd.read_sql_query("SELECT * FROM personal_info", engine)
# Out:
#         id    lastName           age  Unnamed: 0  gender  \
# 0     8760       BEZOS  54 years old          52    None
# 1     7500       GATES  62 years old          53    Male
# 2     5751     bufFETT  87 years old          54       M
# 3     8365     arNAULt  69 years old          55    None
# 4     5328  zUCKERBERg          1985          56    None
# ...    ...         ...           ...         ...     ...
# 2203  4506        ZHAO  51 years old        2255       M
# 2204  6986        zhOU  55 years old        2256    None
# 2205  1828         zHU  51 years old        2257       M
# 2206  6448        ZHUO  52 years old        2258  Female
# 2207  1860       zoRLu  54 years old        2259       M
#
#                          country  \
# 0                  United States
# 1                           None
# 2                           None
# 3                         France
# 4                  United States
# ...                          ...
# 2203                       China
# ...

# %%
pd.read_sql_query("SELECT * FROM business_info", engine)
# Out:
#         id  Unnamed: 0                                           Source  \
# 0     8760          52                           Technology  ==> Amazon
# 1     7500          53                        Technology  ==> Microsoft
# 2     5751          54  Finance and Investments  ==> Berkshire Hathaway
# 3     8365          55                       Fashion & Retail  ==> LVMH
# 4     5328          56                         Technology  ==> Facebook
# ...    ...         ...                                              ...
# 2203  4506        2255     Fashion & Retail  ==> fashion, entertainment
# 2204  6986        2256          Manufacturing  ==> electrical equipment
# 2205  1828        2257          Manufacturing  ==> electrical equipment
# 2206  6448        2258        Manufacturing  ==> printed circuit boards
# 2207  1860        2259                     Diversified  ==> diversified
#
#            worth          worthChange realTimeWorth  realTimePosition
# ...

# %%
pd.read_sql_query("SELECT * FROM rank_info", engine)
# Out:
#         id                         name  position  Unnamed: 0
# 0     6367  ananT ASAVABHOKHIN & family       NaN           0
# 1     7613               arash FERDOWSI       NaN           1
# 2     6139     banthoon LAMSAM & FAMILY       NaN           2
# 3     5671       bill ADDERLEY & family       NaN           3
# 4     2117            boris zINGArevich       NaN           4
# ...    ...                          ...       ...         ...
# 2255  4506               zhao XIAOQiang    2204.0        2255
# 2256  6986              zHOU LIANgzhang    2205.0        2256
# 2257  1828                 zhu XINGMIng    2206.0        2257
# 2258  6448                     ZHUO JUN    2207.0        2258
# 2259  1860                  olguN ZOrlu    2208.0        2259
#
# [2260 rows x 4 columns]

# %%
pd.read_sql_query('''SELECT *
FROM rank_info
LEFT JOIN business_info
ON rank_info.id = business_info.id
LEFT JOIN personal_info
ON rank_info.id = personal_info.id 
order by "position" ASC;'''
, engine)
# Out:
#         id                         name  position  Unnamed: 0      id  \
# 0     6367  ananT ASAVABHOKHIN & family       NaN           0     NaN
# 1     7613               arash FERDOWSI       NaN           1     NaN
# 2     6139     banthoon LAMSAM & FAMILY       NaN           2     NaN
# 3     5671       bill ADDERLEY & family       NaN           3     NaN
# 4     2117            boris zINGArevich       NaN           4     NaN
# ...    ...                          ...       ...         ...     ...
# 2255  4506               zhao XIAOQiang    2204.0        2255  4506.0
# 2256  6986              zHOU LIANgzhang    2205.0        2256  6986.0
# 2257  1828                 zhu XINGMIng    2206.0        2257  1828.0
# 2258  6448                     ZHUO JUN    2207.0        2258  6448.0
# 2259  1860                  olguN ZOrlu    2208.0        2259  1860.0
#
#       Unnamed: 0                                        Source     worth  \
# ...

# %%
pd.read_sql_query('''SELECT name, lastName, "position" , worth, "source", age, gender, country
FROM rank_info
LEFT JOIN business_info
ON rank_info.id = business_info.id
LEFT JOIN personal_info
ON rank_info.id = personal_info.id 
order by "position" ASC;'''
, engine)
# Out:
#                              name lastName  position     worth  \
# 0     ananT ASAVABHOKHIN & family     None       NaN      None
# 1                  arash FERDOWSI     None       NaN      None
# 2        banthoon LAMSAM & FAMILY     None       NaN      None
# 3          bill ADDERLEY & family     None       NaN      None
# 4               boris zINGArevich     None       NaN      None
# ...                           ...      ...       ...       ...
# 2255               zhao XIAOQiang     ZHAO    2204.0  1.0 BUSD
# 2256              zHOU LIANgzhang     zhOU    2205.0  1.0 BUSD
# 2257                 zhu XINGMIng      zHU    2206.0  1.0 BUSD
# 2258                     ZHUO JUN     ZHUO    2207.0  1.0 BUSD
# 2259                  olguN ZOrlu    zoRLu    2208.0  1.0 BUSD
#
#                                             Source           age  gender  \
# 0                                             None          None    None
# ...

# %%
global_net_worth_list = pd.read_sql_query('''SELECT name, lastName, "position" , worth, "source", age, gender, country
FROM rank_info
LEFT JOIN business_info
ON rank_info.id = business_info.id
LEFT JOIN personal_info
ON rank_info.id = personal_info.id 
order by "position" ASC;'''
, engine)

df_global_net_worth = pd.DataFrame(global_net_worth_list)

# %%
df_global_net_worth
# Out:
#                              name lastName  position     worth  \
# 0     ananT ASAVABHOKHIN & family     None       NaN      None
# 1                  arash FERDOWSI     None       NaN      None
# 2        banthoon LAMSAM & FAMILY     None       NaN      None
# 3          bill ADDERLEY & family     None       NaN      None
# 4               boris zINGArevich     None       NaN      None
# ...                           ...      ...       ...       ...
# 2255               zhao XIAOQiang     ZHAO    2204.0  1.0 BUSD
# 2256              zHOU LIANgzhang     zhOU    2205.0  1.0 BUSD
# 2257                 zhu XINGMIng      zHU    2206.0  1.0 BUSD
# 2258                     ZHUO JUN     ZHUO    2207.0  1.0 BUSD
# 2259                  olguN ZOrlu    zoRLu    2208.0  1.0 BUSD
#
#                                             Source           age  gender  \
# 0                                             None          None    None
# ...

# %%
filter_nulls = df_global_net_worth['worth'].notnull()

filter_nulls
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2255     True
# 2256     True
# 2257     True
# 2258     True
# 2259     True
# Name: worth, Length: 2260, dtype: bool

# %%
df_global_net_worth[filter_nulls].head(50)
# Out:
#                                   name            lastName  position  \
# 52                          jefF BEZOs               BEZOS       1.0
# 53                          bILL GATES               GATES       2.0
# 54                      WARREN BUFFEtt             bufFETT       3.0
# 55                     bernARD ARNAULT             arNAULt       4.0
# 56                     maRK ZUCKERBERG          zUCKERBERg       5.0
# 57                      amaNCIO ORTega              ortEGa       6.0
# 58                    carlOS SLIM HElu           slIM HELU       7.0
# 59                        chARLES Koch                KOCH       8.0
# 60                          david KOCH                kOCH       9.0
# 61                       larry ELLISON             eLLISOn      10.0
# 62                   mICHAEL BLOOMBErg           BLOOMBERg      11.0
# 63                          LARRY PAGE                paGE      12.0
# 64                         serGEY Brin                BRIN      13.0
# ...

# %% [markdown]
# # Challenge 2 - Working with JSON files
#
# Import the pandas library.

# %%
# your code here

import pandas as pd

# %% [markdown]
# In the next cell, load the data in `nasa.json` in the `data` folder and load it into a pandas dataframe. Name the dataframe `nasa`.

# %%
# your code here

df_json = pd.read_json('/Users/manuelaquino/Bootcamp/dataptmad1120/module-1/importing-exporting-data/data/nasa.json', orient='records')

# %% [markdown]
# Now that we have loaded the data, let's examine it using the `head()` function.

# %%
# your code here

df_json.head()
# Out:
#    :@computed_region_cbhk_fwbd  :@computed_region_nnqa_25f4  fall  \
# 0                          NaN                          NaN  Fell
# 1                          NaN                          NaN  Fell
# 2                          NaN                          NaN  Fell
# 3                          NaN                          NaN  Fell
# 4                          NaN                          NaN  Fell
#
#                                          geolocation   id      mass      name  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0    Aachen
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0    Aarhus
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0      Abee
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0  Acapulco
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....  370     780.0   Achiras
#
#   nametype     recclass    reclat    reclong                     year
# ...

# %% [markdown]
# #### The `value_counts()` function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the `value_counts()` function to determine the frequency of all types of asteroid landings by applying the function to the `fall` column.

# %%
# your code here

df_json['fall'].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the `orient=records` argument and name the file `nasa-output.json`. Remember to save the file inside the `data` folder.

# %%
# your code here

df_json.to_json(f'/Users/manuelaquino/Bootcamp/dataptmad1120/module-1/importing-exporting-data/data/nasa-output.json', orient='records')

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# CSV files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a CSV file into a dataframe directly from a URL without having to load the file first and then transform it. The dataset we will be using contains information about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# your code here

import pandas as pd

shuttle = pd.read_csv(tst_url, sep=' ', names=cols)

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
# your code here
shuttle.head()
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated, that we are not saving the index column and that the file is saved inside the `data` folder.

# %%
# your code here

shuttle.to_csv(f'/Users/manuelaquino/Bootcamp/dataptmad1120/module-1/importing-exporting-data/data/shuttle.csv', sep=",", index=False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the `data` folder. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# your code here

astronaut = pd.read_excel('/Users/manuelaquino/Bootcamp/dataptmad1120/module-1/importing-exporting-data/data/astronauts.xls')

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# your code here

astronaut.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active 1967-05-17  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired 1936-03-07   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired 1946-03-03     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired 1951-05-20  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired 1930-01-20  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# your code here

astronaut['Undergraduate Major'].value_counts()
# Out:
# Physics                                             35
# Aerospace Engineering                               33
# Mechanical Engineering                              30
# Aeronautical Engineering                            28
# Electrical Engineering                              23
#                                                     ..
# Geosciences                                          1
# Mathematical & Electrical Science                    1
# Physiology                                           1
# Computer & Systems Engineering                       1
# Engineering Sciences; Astronautics & Mathematics     1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a **tab separated file** using the `to_csv` function. Call the file `astronaut.csv`. Remember to remove the index column and save the file in the `data` folder.

# %%
# your code here

astronaut.to_csv(f'/Users/manuelaquino/Bootcamp/dataptmad1120/module-1/importing-exporting-data/data/astronaut.csv', sep="\t", index=False)

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.
#
# Look in Google for a way to retrieve this data!

# %%
# your code here

fertility_dataset_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00244/fertility_Diagnosis.txt'

# %% [markdown]
# # Fertility Dataset - Attribute Information:
#
# `Season in which the analysis was performed.` 1) winter, 2) spring, 3) Summer, 4) fall. (-1, -0.33, 0.33, 1)
#
# `Age at the time of analysis.` 18-36 (0, 1)
#
# `Childish diseases` (ie , chicken pox, measles, mumps, polio) 1) yes, 2) no. (0, 1)
#
# `Accident or serious trauma` 1) yes, 2) no. (0, 1)
#
# `Surgical intervention` 1) yes, 2) no. (0, 1)
#
# `High fevers in the last year` 1) less than three months ago, 2) more than three months ago, 3) no. (-1, 0, 1)
#
# `Frequency of alcohol consumption` 1) several times a day, 2) every day, 3) several times a week, 4) once a week, 5) hardly ever or never (0, 1)
#
# `Smoking habit` 1) never, 2) occasional 3) daily. (-1, 0, 1)
#
# `Number of hours spent sitting per day` ene-16 (0, 1)
#
# `Output`: Diagnosis normal (N), altered (O)

# %%
fertility_dataset_columns = ['Season', 'Age', 'Childish Diseases',
                             'Accident or serious trauma',
                             'Surgical intervention',
                             'High fevers in the LY',
                             'Frequency of alcohol consumption', 
                             'Smoking habit', 
                             '# of hrs spent sitting per day', 
                             'Output']

# %%
fertility = pd.read_csv(fertility_dataset_url, sep = ',', names = fertility_dataset_columns)

# %%
fertility.head(25)
# Out:
#     Season   Age  Childish Diseases  Accident or serious trauma  \
# 0    -0.33  0.69                  0                           1
# 1    -0.33  0.94                  1                           0
# 2    -0.33  0.50                  1                           0
# 3    -0.33  0.75                  0                           1
# 4    -0.33  0.67                  1                           1
# 5    -0.33  0.67                  1                           0
# 6    -0.33  0.67                  0                           0
# 7    -0.33  1.00                  1                           1
# 8     1.00  0.64                  0                           0
# 9     1.00  0.61                  1                           0
# 10    1.00  0.67                  1                           1
# 11    1.00  0.78                  1                           1
# 12    1.00  0.75                  1                           1
# 13    1.00  0.81                  1                           0
# ...
